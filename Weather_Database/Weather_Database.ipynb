# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | takoradi
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | dwarka
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | zhanaozen
# Processing Record 10 of Set 1 | la asuncion
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | klaksvik
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | sorkjosen
# Processing Record 15 of Set 1 | belmonte
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | kandrian
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | champerico
# Processing Record 22 of Set 1 | mehamn
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | isangel
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | karpathos
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | zhoucheng
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | cabra
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | buraydah
# Processing Record 39 of Set 1 | vostok
# Processing Record 40 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | karratha
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | great yarmouth
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | ballitoville
# Processing Record 49 of Set 1 | faanui
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 2 | jilmah
# City not found. Skipping...
# Processing Record 3 of Set 2 | komsomolskiy
# Processing Record 4 of Set 2 | broken hill
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | beringovskiy
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | vredendal
# Processing Record 10 of Set 2 | brandfort
# Processing Record 11 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | acuna
# City not found. Skipping...
# Processing Record 14 of Set 2 | paris
# Processing Record 15 of Set 2 | beyneu
# Processing Record 16 of Set 2 | troy
# Processing Record 17 of Set 2 | ola
# Processing Record 18 of Set 2 | eureka
# Processing Record 19 of Set 2 | caravelas
# Processing Record 20 of Set 2 | saint-ambroise
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | santa ana
# Processing Record 24 of Set 2 | mariental
# Processing Record 25 of Set 2 | iskateley
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | hasaki
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | pecos
# Processing Record 31 of Set 2 | meadow lake
# Processing Record 32 of Set 2 | nouna
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | pachino
# Processing Record 35 of Set 2 | dingle
# Processing Record 36 of Set 2 | olafsvik
# Processing Record 37 of Set 2 | beloha
# Processing Record 38 of Set 2 | antsohihy
# Processing Record 39 of Set 2 | airai
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | limon
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | rzhev
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | el balyana
# City not found. Skipping...
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | qaanaaq
# Processing Record 48 of Set 2 | orchard homes
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | bitkine
# Processing Record 2 of Set 3 | cherniyiv
# Processing Record 3 of Set 3 | taketoyo
# Processing Record 4 of Set 3 | margate
# Processing Record 5 of Set 3 | bardiyah
# Processing Record 6 of Set 3 | kloulklubed
# Processing Record 7 of Set 3 | manaure
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | ferkessedougou
# Processing Record 10 of Set 3 | terrak
# Processing Record 11 of Set 3 | coquimbo
# Processing Record 12 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | xambioa
# Processing Record 15 of Set 3 | vao
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | corn island
# Processing Record 19 of Set 3 | marienburg
# Processing Record 20 of Set 3 | wangqing
# Processing Record 21 of Set 3 | aksu
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | portales
# Processing Record 24 of Set 3 | chapais
# Processing Record 25 of Set 3 | richards bay
# Processing Record 26 of Set 3 | hamilton
# Processing Record 27 of Set 3 | uarini
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | tongliao
# Processing Record 30 of Set 3 | madimba
# Processing Record 31 of Set 3 | aksarka
# Processing Record 32 of Set 3 | ternate
# Processing Record 33 of Set 3 | hithadhoo
# Processing Record 34 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 3 | peniche
# Processing Record 36 of Set 3 | nortelandia
# Processing Record 37 of Set 3 | okhotsk
# Processing Record 38 of Set 3 | varkaus
# Processing Record 39 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 3 | henties bay
# Processing Record 41 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | bandarbeyla
# Processing Record 44 of Set 3 | pangnirtung
# Processing Record 45 of Set 3 | ouango
# Processing Record 46 of Set 3 | tabou
# Processing Record 47 of Set 3 | port lincoln
# Processing Record 48 of Set 3 | los llanos de aridane
# Processing Record 49 of Set 3 | kapaa
# Processing Record 50 of Set 3 | ampanihy
# Processing Record 1 of Set 4 | olinda
# Processing Record 2 of Set 4 | viedma
# Processing Record 3 of Set 4 | naze
# Processing Record 4 of Set 4 | abnub
# Processing Record 5 of Set 4 | kitui
# Processing Record 6 of Set 4 | gympie
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 4 | poum
# Processing Record 10 of Set 4 | noumea
# Processing Record 11 of Set 4 | tamandare
# Processing Record 12 of Set 4 | curup
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | lazaro cardenas
# Processing Record 15 of Set 4 | gold coast
# Processing Record 16 of Set 4 | vaitape
# Processing Record 17 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 4 | esperance
# Processing Record 19 of Set 4 | calvinia
# Processing Record 20 of Set 4 | inuvik
# Processing Record 21 of Set 4 | umea
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | verkhoyansk
# Processing Record 25 of Set 4 | ambilobe
# Processing Record 26 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 4 | lewiston
# Processing Record 28 of Set 4 | daru
# Processing Record 29 of Set 4 | kusti
# Processing Record 30 of Set 4 | wolgast
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | acapulco
# Processing Record 33 of Set 4 | lubao
# Processing Record 34 of Set 4 | paamiut
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | sterling
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | khomeyn
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | lensk
# Processing Record 43 of Set 4 | prince rupert
# Processing Record 44 of Set 4 | goya
# Processing Record 45 of Set 4 | upernavik
# Processing Record 46 of Set 4 | biak
# Processing Record 47 of Set 4 | grand gaube
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | fort nelson
# Processing Record 50 of Set 4 | bairiki
# Processing Record 1 of Set 5 | horten
# Processing Record 2 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 3 of Set 5 | north bend
# Processing Record 4 of Set 5 | kamina
# Processing Record 5 of Set 5 | ghatanji
# Processing Record 6 of Set 5 | aswan
# Processing Record 7 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 5 | bubaque
# Processing Record 9 of Set 5 | mecca
# Processing Record 10 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 5 | bayji
# Processing Record 12 of Set 5 | herne bay
# Processing Record 13 of Set 5 | daxian
# City not found. Skipping...
# Processing Record 14 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 | mount gambier
# Processing Record 17 of Set 5 | kota kinabalu
# Processing Record 18 of Set 5 | tatawin
# Processing Record 19 of Set 5 | katsuura
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | campbell river
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | makakilo city
# Processing Record 25 of Set 5 | saint-augustin
# Processing Record 26 of Set 5 | westport
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | mount isa
# Processing Record 29 of Set 5 | alice springs
# Processing Record 30 of Set 5 | san felipe
# Processing Record 31 of Set 5 | sao carlos
# Processing Record 32 of Set 5 | buchanan
# Processing Record 33 of Set 5 | emba
# Processing Record 34 of Set 5 | east london
# Processing Record 35 of Set 5 | orange cove
# Processing Record 36 of Set 5 | qafsah
# City not found. Skipping...
# Processing Record 37 of Set 5 | kedrovyy
# Processing Record 38 of Set 5 | tasiilaq
# Processing Record 39 of Set 5 | hay river
# Processing Record 40 of Set 5 | leningradskiy
# Processing Record 41 of Set 5 | coos bay
# Processing Record 42 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | saint anthony
# Processing Record 44 of Set 5 | sibolga
# Processing Record 45 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | moron
# Processing Record 48 of Set 5 | gat
# Processing Record 49 of Set 5 | carnarvon
# Processing Record 50 of Set 5 | jinchang
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | padang
# Processing Record 3 of Set 6 | santa cruz
# Processing Record 4 of Set 6 | norman wells
# Processing Record 5 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 6 | christchurch
# Processing Record 7 of Set 6 | leghorn
# City not found. Skipping...
# Processing Record 8 of Set 6 | thompson
# Processing Record 9 of Set 6 | roald
# Processing Record 10 of Set 6 | bac lieu
# Processing Record 11 of Set 6 | nsanje
# Processing Record 12 of Set 6 | itoman
# Processing Record 13 of Set 6 | coihaique
# Processing Record 14 of Set 6 | ulladulla
# Processing Record 15 of Set 6 | lakhdenpokhya
# Processing Record 16 of Set 6 | green river
# Processing Record 17 of Set 6 | sechura
# Processing Record 18 of Set 6 | thunder bay
# Processing Record 19 of Set 6 | groningen
# Processing Record 20 of Set 6 | dzilam gonzalez
# Processing Record 21 of Set 6 | nouakchott
# Processing Record 22 of Set 6 | sedalia
# Processing Record 23 of Set 6 | jadu
# Processing Record 24 of Set 6 | plaridel
# Processing Record 25 of Set 6 | lasa
# Processing Record 26 of Set 6 | truro
# Processing Record 27 of Set 6 | tammisaari
# Processing Record 28 of Set 6 | kandalaksha
# Processing Record 29 of Set 6 | mastic beach
# Processing Record 30 of Set 6 | bagdarin
# Processing Record 31 of Set 6 | phibun mangsahan
# Processing Record 32 of Set 6 | cidreira
# Processing Record 33 of Set 6 | kununurra
# Processing Record 34 of Set 6 | samarai
# Processing Record 35 of Set 6 | arlington
# Processing Record 36 of Set 6 | palora
# Processing Record 37 of Set 6 | labuhan
# Processing Record 38 of Set 6 | olavarria
# Processing Record 39 of Set 6 | yumen
# Processing Record 40 of Set 6 | kruisfontein
# Processing Record 41 of Set 6 | hutchinson
# Processing Record 42 of Set 6 | sesheke
# Processing Record 43 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 6 | mayo
# Processing Record 45 of Set 6 | yulara
# Processing Record 46 of Set 6 | chuy
# Processing Record 47 of Set 6 | otjiwarongo
# Processing Record 48 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | saquena
# Processing Record 1 of Set 7 | taoudenni
# Processing Record 2 of Set 7 | kailua
# Processing Record 3 of Set 7 | awbari
# Processing Record 4 of Set 7 | cockburn town
# Processing Record 5 of Set 7 | zadar
# Processing Record 6 of Set 7 | sarrebourg
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | ondjiva
# Processing Record 9 of Set 7 | navashino
# Processing Record 10 of Set 7 | anloga
# Processing Record 11 of Set 7 | solwezi
# Processing Record 12 of Set 7 | asau
# Processing Record 13 of Set 7 | maniitsoq
# Processing Record 14 of Set 7 | te anau
# Processing Record 15 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 | tsumeb
# Processing Record 17 of Set 7 | cuencame
# Processing Record 18 of Set 7 | quang ngai
# Processing Record 19 of Set 7 | tazovskiy
# Processing Record 20 of Set 7 | lavras
# Processing Record 21 of Set 7 | egvekinot
# Processing Record 22 of Set 7 | ornskoldsvik
# Processing Record 23 of Set 7 | urengoy
# Processing Record 24 of Set 7 | neiafu
# Processing Record 25 of Set 7 | muscat
# Processing Record 26 of Set 7 | san juan
# Processing Record 27 of Set 7 | lock haven
# Processing Record 28 of Set 7 | port macquarie
# Processing Record 29 of Set 7 | houston
# Processing Record 30 of Set 7 | lanxi
# Processing Record 31 of Set 7 | shambu
# Processing Record 32 of Set 7 | karaj
# Processing Record 33 of Set 7 | portpatrick
# City not found. Skipping...
# Processing Record 34 of Set 7 | aklavik
# Processing Record 35 of Set 7 | nerchinskiy zavod
# Processing Record 36 of Set 7 | beruwala
# Processing Record 37 of Set 7 | puerto colombia
# Processing Record 38 of Set 7 | ayan
# Processing Record 39 of Set 7 | lewistown
# Processing Record 40 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 7 | keti bandar
# Processing Record 42 of Set 7 | yondo
# Processing Record 43 of Set 7 | villazon
# Processing Record 44 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 7 | vigrestad
# Processing Record 46 of Set 7 | pangkalanbuun
# Processing Record 47 of Set 7 | nalut
# Processing Record 48 of Set 7 | zhuhai
# Processing Record 49 of Set 7 | inhambane
# Processing Record 50 of Set 7 | canico
# Processing Record 1 of Set 8 | bilma
# Processing Record 2 of Set 8 | igarka
# Processing Record 3 of Set 8 | sao filipe
# Processing Record 4 of Set 8 | rock sound
# Processing Record 5 of Set 8 | bacolod
# Processing Record 6 of Set 8 | berdigestyakh
# Processing Record 7 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 8 | sorong
# Processing Record 9 of Set 8 | ticleni
# Processing Record 10 of Set 8 | asyut
# Processing Record 11 of Set 8 | herat
# Processing Record 12 of Set 8 | ahipara
# Processing Record 13 of Set 8 | buala
# Processing Record 14 of Set 8 | windsor locks
# Processing Record 15 of Set 8 | arica
# Processing Record 16 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 8 | hualmay
# Processing Record 18 of Set 8 | caucaia
# Processing Record 19 of Set 8 | bani walid
# Processing Record 20 of Set 8 | avarua
# Processing Record 21 of Set 8 | najran
# Processing Record 22 of Set 8 | martapura
# Processing Record 23 of Set 8 | ruidoso
# Processing Record 24 of Set 8 | iisalmi
# Processing Record 25 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 8 | paragould
# Processing Record 27 of Set 8 | atasu
# Processing Record 28 of Set 8 | scarborough
# Processing Record 29 of Set 8 | ostrovnoy
# Processing Record 30 of Set 8 | baykit
# Processing Record 31 of Set 8 | duncan
# Processing Record 32 of Set 8 | sambava
# Processing Record 33 of Set 8 | callaway
# Processing Record 34 of Set 8 | jiuquan
# Processing Record 35 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 8 | arlit
# Processing Record 37 of Set 8 | salalah
# Processing Record 38 of Set 8 | nanakuli
# Processing Record 39 of Set 8 | iqaluit
# Processing Record 40 of Set 8 | remetea
# Processing Record 41 of Set 8 | eyl
# Processing Record 42 of Set 8 | bayanday
# Processing Record 43 of Set 8 | bambanglipuro
# Processing Record 44 of Set 8 | rosarito
# Processing Record 45 of Set 8 | nizwa
# Processing Record 46 of Set 8 | bakchar
# Processing Record 47 of Set 8 | valdemarpils
# Processing Record 48 of Set 8 | luang prabang
# Processing Record 49 of Set 8 | kenai
# Processing Record 50 of Set 8 | mumford
# Processing Record 1 of Set 9 | chumikan
# Processing Record 2 of Set 9 | la ronge
# Processing Record 3 of Set 9 | kaeo
# Processing Record 4 of Set 9 | mikhaylovskoye
# Processing Record 5 of Set 9 | khatanga
# Processing Record 6 of Set 9 | bahia blanca
# Processing Record 7 of Set 9 | portland
# Processing Record 8 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 9 | kodiak
# Processing Record 11 of Set 9 | kahului
# Processing Record 12 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 9 | salamanca
# Processing Record 14 of Set 9 | banjar
# Processing Record 15 of Set 9 | plouzane
# Processing Record 16 of Set 9 | pasni
# Processing Record 17 of Set 9 | contamana
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | yuli
# Processing Record 20 of Set 9 | millau
# Processing Record 21 of Set 9 | mabua
# Processing Record 22 of Set 9 | alofi
# Processing Record 23 of Set 9 | salinas
# Processing Record 24 of Set 9 | boulder city
# Processing Record 25 of Set 9 | thinadhoo
# Processing Record 26 of Set 9 | lavrentiya
# Processing Record 27 of Set 9 | chernyshkovskiy
# Processing Record 28 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 29 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 30 of Set 9 | fairbanks
# Processing Record 31 of Set 9 | tromso
# Processing Record 32 of Set 9 | kelvington
# Processing Record 33 of Set 9 | mombetsu
# Processing Record 34 of Set 9 | nabire
# Processing Record 35 of Set 9 | diapaga
# Processing Record 36 of Set 9 | batagay-alyta
# Processing Record 37 of Set 9 | tawzar
# City not found. Skipping...
# Processing Record 38 of Set 9 | surab
# Processing Record 39 of Set 9 | karamken
# City not found. Skipping...
# Processing Record 40 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 42 of Set 9 | huarmey
# Processing Record 43 of Set 9 | ust-kan
# Processing Record 44 of Set 9 | mahebourg
# Processing Record 45 of Set 9 | luderitz
# Processing Record 46 of Set 9 | ponta delgada
# Processing Record 47 of Set 9 | bonthe
# Processing Record 48 of Set 9 | angra
# City not found. Skipping...
# Processing Record 49 of Set 9 | kodinsk
# Processing Record 50 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 10 | dunedin
# Processing Record 2 of Set 10 | srednekolymsk
# Processing Record 3 of Set 10 | bogovarovo
# Processing Record 4 of Set 10 | soyo
# Processing Record 5 of Set 10 | tautira
# Processing Record 6 of Set 10 | juneau
# Processing Record 7 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 10 | duz
# City not found. Skipping...
# Processing Record 9 of Set 10 | romanovo
# Processing Record 10 of Set 10 | alcudia
# Processing Record 11 of Set 10 | ndele
# Processing Record 12 of Set 10 | longjiang
# Processing Record 13 of Set 10 | waingapu
# Processing Record 14 of Set 10 | san cristobal
# Processing Record 15 of Set 10 | souillac
# Processing Record 16 of Set 10 | kusa
# Processing Record 17 of Set 10 | whitefish
# Processing Record 18 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 10 | cascais
# Processing Record 20 of Set 10 | sao felix do xingu
# Processing Record 21 of Set 10 | pevek
# Processing Record 22 of Set 10 | pandan
# Processing Record 23 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 10 | tezu
# Processing Record 25 of Set 10 | ciudad del maiz
# Processing Record 26 of Set 10 | shenjiamen
# Processing Record 27 of Set 10 | kavieng
# Processing Record 28 of Set 10 | jalu
# Processing Record 29 of Set 10 | jumla
# Processing Record 30 of Set 10 | tricase
# Processing Record 31 of Set 10 | stevenage
# Processing Record 32 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 33 of Set 10 | rayong
# Processing Record 34 of Set 10 | mulanje
# Processing Record 35 of Set 10 | raduzhnyy
# Processing Record 36 of Set 10 | ixtapa
# Processing Record 37 of Set 10 | grindavik
# Processing Record 38 of Set 10 | half moon bay
# Processing Record 39 of Set 10 | fayaoue
# Processing Record 40 of Set 10 | gimli
# Processing Record 41 of Set 10 | progreso
# Processing Record 42 of Set 10 | broome
# Processing Record 43 of Set 10 | nizhniy baskunchak
# Processing Record 44 of Set 10 | bundaberg
# Processing Record 45 of Set 10 | bud
# Processing Record 46 of Set 10 | takhtamygda
# Processing Record 47 of Set 10 | vallenar
# Processing Record 48 of Set 10 | akureyri
# Processing Record 49 of Set 10 | kholtoson
# Processing Record 50 of Set 10 | inverness
# Processing Record 1 of Set 11 | bondo
# Processing Record 2 of Set 11 | kilis
# Processing Record 3 of Set 11 | benito juarez
# Processing Record 4 of Set 11 | hokitika
# Processing Record 5 of Set 11 | tshikapa
# Processing Record 6 of Set 11 | teacapan
# Processing Record 7 of Set 11 | zhigansk
# Processing Record 8 of Set 11 | ouahigouya
# Processing Record 9 of Set 11 | ust-kuyga
# Processing Record 10 of Set 11 | arroyo
# Processing Record 11 of Set 11 | kokopo
# Processing Record 12 of Set 11 | mezen
# Processing Record 13 of Set 11 | longyearbyen
# Processing Record 14 of Set 11 | privolzhsk
# Processing Record 15 of Set 11 | shimoda
# Processing Record 16 of Set 11 | santa maria
# Processing Record 17 of Set 11 | superior
# Processing Record 18 of Set 11 | dongsheng
# Processing Record 19 of Set 11 | vihari
# Processing Record 20 of Set 11 | tashtyp
# Processing Record 21 of Set 11 | teguise
# Processing Record 22 of Set 11 | nagaur
# Processing Record 23 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 11 | flinders
# Processing Record 25 of Set 11 | batemans bay
# Processing Record 26 of Set 11 | lagoa
# Processing Record 27 of Set 11 | constitucion
# Processing Record 28 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 11 | coahuayana
# Processing Record 30 of Set 11 | lasem
# Processing Record 31 of Set 11 | kargasok
# Processing Record 32 of Set 11 | imbituba
# Processing Record 33 of Set 11 | porto novo
# Processing Record 34 of Set 11 | toungoo
# City not found. Skipping...
# Processing Record 35 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 11 | caceres
# Processing Record 37 of Set 11 | perelyub
# Processing Record 38 of Set 11 | sorland
# Processing Record 39 of Set 11 | tecoanapa
# Processing Record 40 of Set 11 | puerto baquerizo moreno
# Processing Record 41 of Set 11 | asimion
# Processing Record 42 of Set 11 | cape girardeau
# Processing Record 43 of Set 11 | maracas
# Processing Record 44 of Set 11 | escanaba
# Processing Record 45 of Set 11 | mingaora
# Processing Record 46 of Set 11 | metro
# Processing Record 47 of Set 11 | iberia
# Processing Record 48 of Set 11 | oriximina
# Processing Record 49 of Set 11 | rio grande
# Processing Record 50 of Set 11 | parchim
# Processing Record 1 of Set 12 | tuatapere
# Processing Record 2 of Set 12 | le port
# Processing Record 3 of Set 12 | nome
# Processing Record 4 of Set 12 | pemba
# Processing Record 5 of Set 12 | ancud
# Processing Record 6 of Set 12 | sayyan
# Processing Record 7 of Set 12 | tevaitoa
# Processing Record 8 of Set 12 | fortuna
# Processing Record 9 of Set 12 | bima
# Processing Record 10 of Set 12 | mizdah
# Processing Record 11 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 12 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 13 of Set 12 | adrar
# Processing Record 14 of Set 12 | yilan
# Processing Record 15 of Set 12 | cabo san lucas
# Processing Record 16 of Set 12 | marsabit
# Processing Record 17 of Set 12 | mormugao
# Processing Record 18 of Set 12 | lang son
# Processing Record 19 of Set 12 | goderich
# Processing Record 20 of Set 12 | itarema
# Processing Record 21 of Set 12 | kutum
# Processing Record 22 of Set 12 | gusau
# Processing Record 23 of Set 12 | college
# Processing Record 24 of Set 12 | pathalgaon
# Processing Record 25 of Set 12 | gogrial
# Processing Record 26 of Set 12 | varberg
# Processing Record 27 of Set 12 | kamenka
# Processing Record 28 of Set 12 | ambon
# Processing Record 29 of Set 12 | ugoofaaru
# Processing Record 30 of Set 12 | namatanai
# Processing Record 31 of Set 12 | slave lake
# Processing Record 32 of Set 12 | bilibino
# Processing Record 33 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 34 of Set 12 | salmas
# Processing Record 35 of Set 12 | uyskoye
# Processing Record 36 of Set 12 | salvador
# Processing Record 37 of Set 12 | samana
# Processing Record 38 of Set 12 | pierre
# Processing Record 39 of Set 12 | umm kaddadah
# Processing Record 40 of Set 12 | tulu bolo
# Processing Record 41 of Set 12 | lincoln
# Processing Record 42 of Set 12 | praya
# Processing Record 43 of Set 12 | orange walk
# Processing Record 44 of Set 12 | takestan
# Processing Record 45 of Set 12 | cururupu
# Processing Record 46 of Set 12 | new haven
# Processing Record 47 of Set 12 | seoul
# Processing Record 48 of Set 12 | san patricio
# Processing Record 49 of Set 12 | carutapera
# Processing Record 50 of Set 12 | tual
# Processing Record 1 of Set 13 | saint-louis
# Processing Record 2 of Set 13 | eregli
# Processing Record 3 of Set 13 | sobolevo
# Processing Record 4 of Set 13 | vardo
# Processing Record 5 of Set 13 | zhigalovo
# Processing Record 6 of Set 13 | ajdabiya
# Processing Record 7 of Set 13 | rawah
# Processing Record 8 of Set 13 | buritizeiro
# Processing Record 9 of Set 13 | riyadh
# Processing Record 10 of Set 13 | belaya gora
# Processing Record 11 of Set 13 | torrington
# Processing Record 12 of Set 13 | nizhnevartovsk
# Processing Record 13 of Set 13 | amapa
# Processing Record 14 of Set 13 | waipawa
# Processing Record 15 of Set 13 | el dorado
# Processing Record 16 of Set 13 | pemangkat
# Processing Record 17 of Set 13 | mitsamiouli
# Processing Record 18 of Set 13 | gotsu
# Processing Record 19 of Set 13 | isaccea
# Processing Record 20 of Set 13 | monrovia
# Processing Record 21 of Set 13 | deputatskiy
# Processing Record 22 of Set 13 | qaqortoq
# Processing Record 23 of Set 13 | wahiawa
# Processing Record 24 of Set 13 | perustica
# City not found. Skipping...
# Processing Record 25 of Set 13 | columbia
# Processing Record 26 of Set 13 | pacific grove
# Processing Record 27 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 13 | falun
# Processing Record 29 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 30 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 13 | canavieiras
# Processing Record 32 of Set 13 | kavaratti
# Processing Record 33 of Set 13 | ahuimanu
# Processing Record 34 of Set 13 | brae
# Processing Record 35 of Set 13 | ye
# City not found. Skipping...
# Processing Record 36 of Set 13 | ngaoundere
# Processing Record 37 of Set 13 | boca do acre
# Processing Record 38 of Set 13 | the valley
# Processing Record 39 of Set 13 | fukuma
# Processing Record 40 of Set 13 | georgiyevka
# Processing Record 41 of Set 13 | yanam
# Processing Record 42 of Set 13 | safaga
# Processing Record 43 of Set 13 | xam nua
# Processing Record 44 of Set 13 | ouadda
# Processing Record 45 of Set 13 | tura
# Processing Record 46 of Set 13 | angoram
# Processing Record 47 of Set 13 | buford
# Processing Record 48 of Set 13 | penzance
# Processing Record 49 of Set 13 | balikpapan
# Processing Record 50 of Set 13 | norrtalje
# Processing Record 1 of Set 14 | sur
# Processing Record 2 of Set 14 | adre
# Processing Record 3 of Set 14 | palmer
# Processing Record 4 of Set 14 | le vauclin
# Processing Record 5 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 14 | quatre cocos
# Processing Record 7 of Set 14 | aykhal
# Processing Record 8 of Set 14 | vila velha
# Processing Record 9 of Set 14 | mao
# Processing Record 10 of Set 14 | buluang
# Processing Record 11 of Set 14 | ucluelet
# Processing Record 12 of Set 14 | escada
# Processing Record 13 of Set 14 | victor harbor
# Processing Record 14 of Set 14 | tarata
# Processing Record 15 of Set 14 | paz de ariporo
# City not found. Skipping...
# Processing Record 16 of Set 14 | kaputa
# Processing Record 17 of Set 14 | den helder
# Processing Record 18 of Set 14 | solnechnyy
# Processing Record 19 of Set 14 | nagato
# Processing Record 20 of Set 14 | juegang
# Processing Record 21 of Set 14 | nuevo ideal
# Processing Record 22 of Set 14 | anuradhapura
# Processing Record 23 of Set 14 | roebourne
# Processing Record 24 of Set 14 | birao
# Processing Record 25 of Set 14 | sapouy
# Processing Record 26 of Set 14 | bonfim
# Processing Record 27 of Set 14 | srandakan
# Processing Record 28 of Set 14 | yaan
# Processing Record 29 of Set 14 | tarko-sale
# Processing Record 30 of Set 14 | kant
# Processing Record 31 of Set 14 | kalmunai
# Processing Record 32 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 33 of Set 14 | ust-nera
# Processing Record 34 of Set 14 | corvallis
# Processing Record 35 of Set 14 | san quintin
# Processing Record 36 of Set 14 | moengo
# Processing Record 37 of Set 14 | briancon
# Processing Record 38 of Set 14 | kanchanaburi
# Processing Record 39 of Set 14 | fiumicino
# Processing Record 40 of Set 14 | strezhevoy
# Processing Record 41 of Set 14 | leirvik
# Processing Record 42 of Set 14 | whitman
# Processing Record 43 of Set 14 | aguas vermelhas
# Processing Record 44 of Set 14 | tambura
# Processing Record 45 of Set 14 | lokot
# Processing Record 46 of Set 14 | nuuk
# Processing Record 47 of Set 14 | holalkere
# Processing Record 48 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 14 | hambantota
# Processing Record 50 of Set 14 | pokrovsk
# Processing Record 1 of Set 15 | cachoeira do sul
# Processing Record 2 of Set 15 | kataysk
# Processing Record 3 of Set 15 | manado
# Processing Record 4 of Set 15 | ati
# Processing Record 5 of Set 15 | ous
# Processing Record 6 of Set 15 | hit
# Processing Record 7 of Set 15 | bafq
# Processing Record 8 of Set 15 | mazagao
# Processing Record 9 of Set 15 | krasnoselkup
# Processing Record 10 of Set 15 | barra
# Processing Record 11 of Set 15 | kilimatinde
# Processing Record 12 of Set 15 | chekmagush
# Processing Record 13 of Set 15 | albi
# Processing Record 14 of Set 15 | port hedland
# Processing Record 15 of Set 15 | honiara
# Processing Record 16 of Set 15 | luanda
# Processing Record 17 of Set 15 | wanning
# Processing Record 18 of Set 15 | pisco
# Processing Record 19 of Set 15 | tabarqah
# City not found. Skipping...
# Processing Record 20 of Set 15 | knysna
# Processing Record 21 of Set 15 | ust-tsilma
# Processing Record 22 of Set 15 | eucaliptus
# Processing Record 23 of Set 15 | monaco-ville
# Processing Record 24 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 15 | gazli
# Processing Record 26 of Set 15 | launceston
# Processing Record 27 of Set 15 | chemax
# Processing Record 28 of Set 15 | nicosia
# Processing Record 29 of Set 15 | las vegas
# Processing Record 30 of Set 15 | babstovo
# Processing Record 31 of Set 15 | muroto
# Processing Record 32 of Set 15 | mareeba
# Processing Record 33 of Set 15 | paarl
# Processing Record 34 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 15 | kangaatsiaq
# Processing Record 36 of Set 15 | bulungu
# Processing Record 37 of Set 15 | gigmoto
# Processing Record 38 of Set 15 | liwale
# Processing Record 39 of Set 15 | chama
# Processing Record 40 of Set 15 | cap malheureux
# Processing Record 41 of Set 15 | bluefield
# Processing Record 42 of Set 15 | macae
# Processing Record 43 of Set 15 | maarianhamina
# Processing Record 44 of Set 15 | yoichi
# Processing Record 45 of Set 15 | pochutla
# Processing Record 46 of Set 15 | anadyr
# Processing Record 47 of Set 15 | valparaiso
# Processing Record 48 of Set 15 | la rioja
# Processing Record 49 of Set 15 | danville
# Processing Record 50 of Set 15 | korla
# Processing Record 1 of Set 16 | sohbatpur
# Processing Record 2 of Set 16 | mangrol
# Processing Record 3 of Set 16 | camacha
# Processing Record 4 of Set 16 | gazanjyk
# Processing Record 5 of Set 16 | pouebo
# Processing Record 6 of Set 16 | camopi
# Processing Record 7 of Set 16 | fairhaven
# Processing Record 8 of Set 16 | darhan
# Processing Record 9 of Set 16 | douglas
# Processing Record 10 of Set 16 | dianopolis
# City not found. Skipping...
# Processing Record 11 of Set 16 | kajaani
# Processing Record 12 of Set 16 | tselinnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Takoradi      GH   4.8845   -1.7554     78.15        88          72
# 1            Vaini      TO -21.2000 -175.2000     77.16        78          40
# 2   Severo-Kurilsk      RU  50.6789  156.1250     40.64        73           4
# 3           Dwarka      IN  22.2394   68.9678     78.21        48           0
# 4  Bambous Virieux      MU -20.3428   57.7575     73.65        78          40
#
#    Wind Speed Current Description
# 0        9.69       broken clouds
# 1        8.05    scattered clouds
# 2        9.60           clear sky
# 3        7.31           clear sky
# 4       11.50          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
